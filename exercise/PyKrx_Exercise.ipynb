# %% [markdown]
# <a href="https://colab.research.google.com/github/nell78/web-crawling/blob/main/exercise/PyKrx_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PyKrx
#   - document[https://github.com/sharebook-kr/pykrx]
#   - 네이버, KRX 주가 정보 스크래핑 데이터 제공
#   - 국내 상장 주식, 채권, ETF 등 OHLCV, 거래대금, 펀더멘털, 거래주체 등의

# %%
# !pip install pykrx

# %%
from pykrx import stock

# Ticker 조회
tickers = stock.get_market_ticker_list("20241022")
print(tickers)
# Out:
# ['095570', '006840', '027410', '282330', '138930', '001460', '001465', '001040', '079160', '00104K', '000120', '011150', '011155', '001045', '097950', '097955', '000480', '000590', '012030', '016610', '005830', '000990', '139130', '001530', '000210', '000215', '375500', '37550L', '37550K', '007340', '004840', '155660', '069730', '017860', '017940', '365550', '383220', '007700', '114090', '078930', '006360', '001250', '007070', '078935', '012630', '039570', '089470', '294870', '009540', '267250', '267270', '443060', '071970', '010620', '322000', '042670', '267260', '329180', '097230', '014790', '003580', '204320', '060980', '011200', '035000', '002460', '487570', '298050', '003560', '175330', '234080', '001060', '001067', '001065', '096760', '105560', '432320', '002380', '344820', '009070', '009440', '119650', '092220', '003620', '016380', '001390', '033180', '015590', '001940', '025000', '092230', '000040', '044450', '030200', '033780', '058850', '058860', '093050', '003550', '034220
# ...

# %%
len(tickers)
# Out:
# 958

# %%
for ticker in tickers[:30]:
  print(ticker, stock.get_market_ticker_name(ticker))
# Out:
# 095570 AJ네트웍스
# 006840 AK홀딩스
# 027410 BGF
# 282330 BGF리테일
# 138930 BNK금융지주
# 001460 BYC
# 001465 BYC우
# 001040 CJ
# 079160 CJ CGV
# 00104K CJ4우(전환)
# 000120 CJ대한통운
# 011150 CJ씨푸드
# 011155 CJ씨푸드1우
# 001045 CJ우
# 097950 CJ제일제당
# 097955 CJ제일제당 우
# 000480 CR홀딩스
# 000590 CS홀딩스
# 012030 DB
# 016610 DB금융투자
# 005830 DB손해보험
# 000990 DB하이텍
# 139130 DGB금융지주
# 001530 DI동일
# 000210 DL
# 000215 DL우
# 375500 DL이앤씨
# 37550L DL이앤씨2우(전환)
# 37550K DL이앤씨우
# 007340 DN오토모티브

# %% [markdown]
# ## 일자별 OHLCV 조회

# %%
# 095570 AJ네트웍스
df = stock.get_market_ohlcv_by_date("20241001", "20241022", "095570")
df
# Out:
#               시가    고가    저가    종가     거래량       등락률
# 날짜
# 2024-10-02  4680  4735  4640  4700   48203  0.427350
# 2024-10-04  4800  4800  4675  4735  120416  0.744681
# 2024-10-07  4745  4805  4725  4750   87443  0.316790
# 2024-10-08  4745  4745  4680  4730   91383 -0.421053
# 2024-10-10  4730  4750  4680  4735   85998  0.105708
# 2024-10-11  4690  4780  4690  4755   80126  0.422386
# 2024-10-14  4755  4915  4750  4845  288133  1.892744
# 2024-10-15  4845  4955  4800  4855  249679  0.206398
# 2024-10-16  4870  4975  4865  4970  318581  2.368692
# 2024-10-17  4920  4965  4845  4850  103012 -2.414487
# 2024-10-18  4840  4925  4785  4830   76651 -0.412371
# 2024-10-21  4830  4895  4810  4845   53374  0.310559
# 2024-10-22  4890  4925  4815  4860  168433  0.309598

# %% [markdown]
# ## 여러 개의 종목 OHLCV 수집

# %%
# import time
# for ticker in tickers:
#     df = stock.get_market_ohlcv("20181210", "20181212", ticker)
#     print(df.head()) # 불려온 데이터는 별도의 CSV 파일 형태로 저장하기

#     time.sleep(1)

# %% [markdown]
# ## 전체 종목 시세 조회

# %%
df_all = stock.get_market_ohlcv("20241022")
df_all.head()
# Out:
#             시가      고가      저가      종가     거래량        거래대금   등락률
# 티커
# 095570    4890    4925    4815    4860  168443   822256095  0.31
# 006840   12530   12770   12530   12730    1186    14993680  1.60
# 027410    3635    3635    3560    3595   55225   198115135 -0.83
# 282330  112800  114400  111400  114200   13923  1577390200  0.79
# 138930    9550    9640    9450    9640  695297  6640638620  0.63

# %% [markdown]
# ## fundamental

# %%
df_fundamental = stock.get_market_fundamental("20241022")
df_fundamental.head()
# Out:
#           BPS    PER   PBR    EPS   DIV   DPS
# 티커
# 095570   9326  13.24  0.52    367  5.56   270
# 006840  44339   4.83  0.29   2635  1.57   200
# 027410  17286   4.42  0.21    813  3.34   120
# 282330  62197  10.07  1.84  11337  3.59  4100
# 138930  31746   5.06  0.30   1905  5.29   510

# %% [markdown]
# ## 거래 대금

# %%
# 매개변수 3개 필수(start_date, end_date, ticker)
df_volume = stock.get_market_trading_value_by_date("20241022", "20241022", "095570")
df_volume.head()
# Out:
#                 기관합계      기타법인       개인     외국인합계  전체
# 날짜
# 2024-10-22 -42336985  16286245  9270970  16779770   0

# %% [markdown]
# ## ETF

# %%
etf_tickers = stock.get_etf_ticker_list()
etf_tickers[:10]
# Out:
# ['470320',
#  '466810',
#  '457930',
#  '487750',
#  '445690',
#  '465780',
#  '442260',
#  '159800',
#  '472840',
#  '361580']

# %%
stock.get_etf_ticker_name("470320")
# Out:
# 'BNK 24-11 회사채(AA-이상)액티브'
